# %%
# !pip install transformers torch --quiet

# %%
import torch
from transformers import pipeline, set_seed

device = 0 if torch.cuda.is_available() else -1
generator = pipeline("text-generation", model="gpt2", device=device)
set_seed(42)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def generate_text(prompt, max_length=60):
    result = generator(
        prompt,
        max_length=max_length,
        num_return_sequences=1,
        truncation=True,
        pad_token_id=generator.tokenizer.eos_token_id
    )
    return result[0]["generated_text"]

# %%
test_prompts = [
    "Artificial intelligence is transforming the way we",
    "Once upon a time in a small village,",
    "The future of renewable energy depends on"
]

for prompt in test_prompts:
    output = generate_text(prompt)
    print("INPUT:", prompt)
    print("OUTPUT:", output)
    print("-" * 80)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'pad_token_id', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INPUT: Artificial intelligence is transforming the way we
# OUTPUT: Artificial intelligence is transforming the way we think about the world, and in doing so, it is showing us what we should be doing instead.
#
# The "science fiction" industry is an exciting, fast-growing, profitable and innovative field. We are constantly looking for new ways to understand and interact with our fellow human beings. We think of ourselves as the most intelligent people on the planet. But we have yet to see a truly intelligent, creative, creative community, with any kind of real-world connection to our social and political realities.
#
# To put it simply, we are not at all close to seeing a future where we are all as intelligent as we would like to be. That is not a good thing.
#
# I would point out to you, as a physicist, that when you consider the work of such luminaries as Isaac Asimov and Stephen Hawking, they were not only scientists but also brilliant. But, in my view, it would be wrong to ascribe them all to the same level of scientific sophistication. I am in no way trying to ascribe them all to a single set of basic physical laws, but I have tried to bring them into the broader context of our everyday lives.
#
# This is not a discussion of what we should be thinking about. This is a
# --------------------------------------------------------------------------------
